# %%
import matplotlib.pyplot as plt
import json

def show_learning_log(path):
    # Load data from JSON
    with open(path, 'r') as file:
        data = json.load(file)

    train_loss = data['train_loss']
    train_acc = data['train_acc']
    train_prec = data['train_prec']
    train_rec = data['train_rec']
    train_f1 = data['train_f1']
    valid_loss = data['valid_loss']
    valid_acc = data['valid_acc']
    valid_prec = data['valid_prec']
    valid_rec = data['valid_rec']
    valid_f1 = data['valid_f1']

    epochs = range(1, len(train_loss) + 1)
    epoch_ticks = range(0, len(train_loss)+1, 4)

    # Create subplots
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 8))

    # Plot training and validation loss
    ax1.plot(epochs, train_loss, 'b', label='Training loss')
    ax1.plot(epochs, valid_loss, 'r', label='Validation loss')
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend()
    # ax1.set_xticks(epoch_ticks)

    # Plot training and validation f1
    ax2.plot(epochs, train_f1, 'b', label='Training f1 score')
    ax2.plot(epochs, valid_f1, 'r', label='Validation f1 score')
    ax2.set_title('Training and Validation F1 Score')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('F1 Score')
    ax2.legend()
    # ax2.set_xticks(epoch_ticks)

    # Plot training and validation precision
    ax3.plot(epochs, train_prec, 'b', label='Training precision')
    ax3.plot(epochs, valid_prec, 'r', label='Validation precision')
    ax3.set_title('Training and Validation Precision')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('Precision')
    ax3.legend()
    # ax3.set_xticks(epoch_ticks)

    # Plot training and validation recall
    ax4.plot(epochs, train_rec, 'b', label='Training recall')
    ax4.plot(epochs, valid_rec, 'r', label='Validation recall')
    ax4.set_title('Training and Validation Recall')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Recall')

# %% [markdown]
# # Text only

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/01_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/02_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/04_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/05_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/06_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/07_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/08_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/09_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/10_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text only/11_training_history.json'
show_learning_log(path)

# %% [markdown]
# # Heatmap_only

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/04_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/06_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/07_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/08_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/09_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/10_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/11_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/12_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/13_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/14_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/15_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/20_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/21_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/22_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/23_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/24_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/25_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/26_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/27_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/28_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/30_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/31_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/32_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/33_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/34_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/35_training_history.json'
show_learning_log(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-2dd50bc7a530> in <module>
#       1 path = '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/35_training_history.json'
# ----> 2 show_learning_log(path)
#
# <ipython-input-2-0e05bde22868> in show_learning_log(path)
#       4 def show_learning_log(path):
#       5     # Load data from JSON
# ----> 6     with open(path, 'r') as file:
#       7         data = json.load(file)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: '/work/adapting-CLIP-VGPs/checkpoints/heatmap only/35_training_history.json'

# %% [markdown]
# # Text + heatmap

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/01_training_history.json'
show_learning_log(path)

# %% [markdown]
# ## lr0.005

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/05_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/07_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/05_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/08_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/09_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/10_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/11_training_history.json'
show_learning_log(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91a0d7bb89fb> in <module>
#       1 path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/11_training_history.json'
# ----> 2 show_learning_log(path)
#
# NameError: name 'show_learning_log' is not defined

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/13_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/14_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/20_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/21_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/22_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/23_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/24_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/25_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/26_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/27_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/28_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/30_training_history.json'
show_learning_log(path)

# %%
path = '/work/adapting-CLIP-VGPs/checkpoints/text+heatmap2/31_training_history.json'
show_learning_log(path)
