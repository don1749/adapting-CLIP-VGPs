# %%
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

Flickr30K_BASE = '/work/adapting-CLIP-VGPs/data/flickr/'

im = Image.open(f'{Flickr30K_BASE}/flickr30k_images/2600867924.jpg').convert("RGB")
# Load the uploaded image
# Define the bounding boxes
boxes = {
    # '18': [[7, 151, 107, 339]],
    # '19': [[7, 190, 85, 298]],
    # '20': [[0, 318, 114, 479]],
    '60728': [[269, 37, 413, 308]],
    '60735': [[87, 61, 252, 286]]
}

# Define a list of colors for the bounding boxes
colors = ['red', 'green']

# Draw bounding boxes on the image with different colors
draw = ImageDraw.Draw(im)
for color, (box_id, box_list) in zip(colors, boxes.items()):
    for box in box_list:
        # Each box is defined by the top left x,y and bottom right x,y
        top_left = (box[0], box[1])
        bottom_right = (box[2], box[3])
        draw.rectangle([top_left, bottom_right], outline=color, width=4)

# Display the image
plt.imshow(im)
plt.axis('off')  # Hide the axes
plt.show()

# %%
regions = []
im = Image.open(f'{Flickr30K_BASE}/flickr30k_images/2600867924.jpg').convert("RGB")

for box_id, box_list in boxes.items():
    for idx, box in enumerate(box_list):
        # Each box is defined by the top left x,y and bottom right x,y
        top_left_x, top_left_y, bottom_right_x, bottom_right_y = box
        # Crop the image
        cropped_image = im.crop((top_left_x, top_left_y, bottom_right_x, bottom_right_y))
        regions.append(cropped_image)

# %%
regions[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=144x271 at 0x7F1BBCED1278>

# %%
regions[1].show()
# Out:
# <PIL.Image.Image image mode=RGB size=165x225 at 0x7F1BBCED1160>

# %%
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

Flickr30K_BASE = '/work/adapting-CLIP-VGPs/data/flickr/'

im = Image.open(f'{Flickr30K_BASE}/flickr30k_images/2254913901.jpg').convert("RGB")
# Load the uploaded image
# Define the bounding boxes
boxes = {
#   '37163': [[252, 147, 473, 335]],
  '37164': [[0, 0, 499, 382]],
}

# Define a list of colors for the bounding boxes
colors = ['red', 'green']

# Draw bounding boxes on the image with different colors
draw = ImageDraw.Draw(im)
for color, (box_id, box_list) in zip(colors, boxes.items()):
    for box in box_list:
        # Each box is defined by the top left x,y and bottom right x,y
        top_left = (box[0], box[1])
        bottom_right = (box[2], box[3])
        draw.rectangle([top_left, bottom_right], outline=color, width=4)

# Display the image
plt.imshow(im)
plt.axis('off')  # Hide the axes
plt.show()
